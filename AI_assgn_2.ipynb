# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
def relu(z):
    a = np.maximum(0,z)
    return a

# %%
def initialize_params(layer_sizes):
    params = {}
    for i in range(1, len(layer_sizes)):
        params['W' + str(i)] = np.random.randn(layer_sizes[i], layer_sizes[i-1])*0.01
        params['B' + str(i)] = np.random.randn(layer_sizes[i],1)*0.01
    return params

# %%
def forward_propagation(X_train, params):
    layers = len(params)//2
    values = {}
    for i in range(1, layers+1):
        if i==1:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], X_train) + params['B' + str(i)]
            values['A' + str(i)] = relu(values['Z' + str(i)])
        else:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], values['A' + str(i-1)]) + params['B' + str(i)]
            if i==layers:
                values['A' + str(i)] = values['Z' + str(i)]
            else:
                values['A' + str(i)] = relu(values['Z' + str(i)])
    return values

# %%
def compute_cost(values, Y_train):
    layers = len(values)//2
    Y_pred = values['A' + str(layers)]
    cost = 1/(2*len(Y_train)) * np.sum(np.square(Y_pred - Y_train))
    return cost

# %%
def backward_propagation(params, values, X_train, Y_train):
    layers = len(params)//2
    m = len(Y_train)
    grads = {}
    for i in range(layers,0,-1):
        if i==layers:
            dA = 1/m * (values['A' + str(i)] - Y_train)
            dZ = dA
        else:
            dA = np.dot(params['W' + str(i+1)].T, dZ)
            dZ = np.multiply(dA, np.where(values['A' + str(i)]>=0, 1, 0))
        if i==1:
            grads['W' + str(i)] = 1/m * np.dot(dZ, X_train.T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
        else:
            grads['W' + str(i)] = 1/m * np.dot(dZ,values['A' + str(i-1)].T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    return grads

# %%
def update_params(params, grads, learning_rate):
    layers = len(params)//2
    params_updated = {}
    for i in range(1,layers+1):
        params_updated['W' + str(i)] = params['W' + str(i)] - learning_rate * grads['W' + str(i)]
        params_updated['B' + str(i)] = params['B' + str(i)] - learning_rate * grads['B' + str(i)]
    return params_updated

# %%
def model(X_train, Y_train, layer_sizes, num_iters, learning_rate):
    params = initialize_params(layer_sizes)
    for i in range(num_iters):
        values = forward_propagation(X_train.T, params)
        cost = compute_cost(values, Y_train.T)
        grads = backward_propagation(params, values,X_train.T, Y_train.T)
        params = update_params(params, grads, learning_rate)
        print('Cost at iteration ' + str(i+1) + ' = ' + str(cost) + '\n')
    return params

# %%
def compute_accuracy(X_train, X_test, Y_train, Y_test, params):
    values_train = forward_propagation(X_train.T, params)
    values_test = forward_propagation(X_test.T, params)
    train_acc = np.sqrt(mean_squared_error(Y_train, values_train['A' + str(len(layer_sizes)-1)].T))
    test_acc = np.sqrt(mean_squared_error(Y_test, values_test['A' + str(len(layer_sizes)-1)].T))
    return train_acc, test_acc

# %%
def predict(X, params):
    values = forward_propagation(X.T, params)
    predictions = values['A' + str(len(values)//2)].T
    return predictions

# %%
data = load_boston()                                                              
X,Y = data["data"], data["target"]                                                
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.2)           
layer_sizes = [13, 5, 5, 1]                                                        
num_iters = 1000                                                                  
learning_rate = 0.03                                                             
params = model(X_train, Y_train, layer_sizes, num_iters, learning_rate)           
train_acc, test_acc = compute_accuracy(X_train, X_test, Y_train, Y_test, params)  
print('Root Mean Squared Error on Training Data = ' + str(train_acc))
print('Root Mean Squared Error on Test Data = ' + str(test_acc))
# Out:
# Cost at iteration 1 = 284.46786128218963
#
# Cost at iteration 2 = 284.43049074313177
#
# Cost at iteration 3 = 284.39314084359074
#
# Cost at iteration 4 = 284.35580938635303
#
# Cost at iteration 5 = 284.3184937259282
#
# Cost at iteration 6 = 284.28119219126233
#
# Cost at iteration 7 = 284.24390199456315
#
# Cost at iteration 8 = 284.20661884719345
#
# Cost at iteration 9 = 284.1693426470647
#
# Cost at iteration 10 = 284.1320713483831
#
# Cost at iteration 11 = 284.094805244225
#
# Cost at iteration 12 = 284.057544842711
#
# Cost at iteration 13 = 284.0202924102173
#
# Cost at iteration 14 = 283.9830423644046
#
# Cost at iteration 15 = 283.94579557130754
#
# Cost at iteration 16 = 283.90855253081054
#
# Cost at iteration 17 = 283.87131077927233
#
# Cost at iteration 18 = 283.834062494889
#
# Cost at iteration 19 = 283.79680676782533
#
# Cost at iteration 20 = 283.75955260852055
#
# Cost at iteration 21 = 283.72230733833396
#
# Cost at iteration 22 = 283.68507018611064
#
# Cost at iteration 23 = 283.6478320095479
#
# Cost at iteration 24 = 283.610592882148
#
# Cost at iteration 25 = 283.5733467225256
#
# Cost at iteration 26 = 283.5360973639045
#
# Cost at iteration 27 = 283.4988407809309
#
# Cost at iteration 28 = 283.4615784132322
#
# Cost at iteration 29 = 283.424306032411
#
# Cost at iteration 30 = 283.3870181740901
#
# Cost at iteration 31 = 283.3497086495258
#
# Cost at iteration 32 = 283.31237813115337
#
# Cost at iteration 33 = 283.2750229199944
#
# Cost at iteration 34 = 283.23764011675576
#
# Cost at iteration 35 = 283.2002268297647
#
# Cost at iteration 36 = 283.1627753654577
#
# Cost at iteration 37 = 283.12528700635
#
# Cost at iteration 38 = 283.0877562637417
#
# Cost at iteration 39 = 283.05017523371515
#
# Cost at iteration 40 = 283.0125414619726
#
# Cost at iteration 41 = 282.97485334055773
#
# Cost at iteration 42 = 282.9371033657358
#
# Cost at iteration 43 = 282.89927088779416
#
# Cost at iteration 44 = 282.86135262106274
#
# Cost at iteration 45 = 282.8233410014846
#
# Cost at iteration 46 = 282.7852251988553
#
# Cost at iteration 47 = 282.7469945712838
#
# Cost at iteration 48 = 282.7086324491393
#
# Cost at iteration 49 = 282.6701390817465
#
# Cost at iteration 50 = 282.63151636193714
#
# Cost at iteration 51 = 282.59273487098636
#
# Cost at iteration 52 = 282.55378418069495
#
# Cost at iteration 53 = 282.5146576237598
#
# Cost at iteration 54 = 282.4753564059913
#
# Cost at iteration 55 = 282.43586939701186
#
# Cost at iteration 56 = 282.39612831232887
#
# Cost at iteration 57 = 282.3561311836677
#
# Cost at iteration 58 = 282.31588560112067
#
# Cost at iteration 59 = 282.27537704769634
#
# Cost at iteration 60 = 282.23458402499546
#
# Cost at iteration 61 = 282.193479915287
#
# Cost at iteration 62 = 282.15203427928384
#
# Cost at iteration 63 = 282.1102152858492
#
# Cost at iteration 64 = 282.0679802695463
#
# Cost at iteration 65 = 282.0253066167975
#
# Cost at iteration 66 = 281.98215278091055
#
# Cost at iteration 67 = 281.9384719650428
#
# Cost at iteration 68 = 281.8942119047558
#
# Cost at iteration 69 = 281.8493140321365
#
# Cost at iteration 70 = 281.80371268415627
#
# Cost at iteration 71 = 281.7573340269138
#
# Cost at iteration 72 = 281.7100950050003
#
# Cost at iteration 73 = 281.6619017114607
#
# Cost at iteration 74 = 281.6126476067382
#
# Cost at iteration 75 = 281.5622119192822
#
# Cost at iteration 76 = 281.5104572158188
#
# Cost at iteration 77 = 281.4572260301475
#
# Cost at iteration 78 = 281.40233851545855
#
# Cost at iteration 79 = 281.3455882909569
#
# Cost at iteration 80 = 281.28673688438215
#
# Cost at iteration 81 = 281.2255085589963
#
# Cost at iteration 82 = 281.1615836338248
#
# Cost at iteration 83 = 281.0945898720485
#
# Cost at iteration 84 = 281.0240929782783
#
# Cost at iteration 85 = 280.9495819255631
#
# Cost at iteration 86 = 280.87045502222975
#
# Cost at iteration 87 = 280.78599981589036
#
# Cost at iteration 88 = 280.69536842822026
#
# Cost at iteration 89 = 280.5975491034243
#
# Cost at iteration 90 = 280.491324630473
#
# Cost at iteration 91 = 280.3752241419978
#
# Cost at iteration 92 = 280.2474595546132
#
# Cost at iteration 93 = 280.1058419631318
#
# Cost at iteration 94 = 279.9476799993799
#
# Cost at iteration 95 = 279.76963589769707
#
# Cost at iteration 96 = 279.5675395089406
#
# Cost at iteration 97 = 279.336139810723
#
# Cost at iteration 98 = 279.06876816110815
#
# Cost at iteration 99 = 278.75687805425895
#
# Cost at iteration 100 = 278.38940895676905
#
# Cost at iteration 101 = 277.95189643055903
#
# Cost at iteration 102 = 277.42521157631865
#
# Cost at iteration 103 = 276.783751569686
#
# Cost at iteration 104 = 275.99280604475075
#
# Cost at iteration 105 = 275.0046686577143
#
# Cost at iteration 106 = 273.7528118344064
#
# Cost at iteration 107 = 272.1430341529297
#
# Cost at iteration 108 = 270.03982745249914
#
# Cost at iteration 109 = 267.24515647584167
#
# Cost at iteration 110 = 263.4652522104356
#
# Cost at iteration 111 = 258.25894542599525
#
# Cost at iteration 112 = 250.95959747461012
#
# Cost at iteration 113 = 240.5668504310355
#
# Cost at iteration 114 = 225.6322268836286
#
# Cost at iteration 115 = 204.26812310239592
#
# Cost at iteration 116 = 174.71128106819862
#
# Cost at iteration 117 = 137.39302049094465
#
# Cost at iteration 118 = 98.8994418589225
#
# Cost at iteration 119 = 72.09412897986145
#
# Cost at iteration 120 = 62.224302077504866
#
# Cost at iteration 121 = 60.052295849992724
#
# Cost at iteration 122 = 58.94928080843182
#
# Cost at iteration 123 = 57.9258670684052
#
# Cost at iteration 124 = 56.93781849451375
#
# Cost at iteration 125 = 55.98240805183485
#
# Cost at iteration 126 = 55.05807223794726
#
# Cost at iteration 127 = 54.16348658761924
#
# Cost at iteration 128 = 53.29752343367842
#
# Cost at iteration 129 = 52.45922834090536
#
# Cost at iteration 130 = 51.64780171830613
#
# Cost at iteration 131 = 50.86255908538601
#
# Cost at iteration 132 = 50.102935612548904
#
# Cost at iteration 133 = 49.368484577644594
#
# Cost at iteration 134 = 48.65881505649763
#
# Cost at iteration 135 = 47.97363013597411
#
# Cost at iteration 136 = 47.31269302707661
#
# Cost at iteration 137 = 46.675821505852475
#
# Cost at iteration 138 = 46.06287217184412
#
# Cost at iteration 139 = 45.473769962139365
#
# Cost at iteration 140 = 44.90841952114058
#
# Cost at iteration 141 = 44.36658165185294
#
# Cost at iteration 142 = 43.84812495935634
#
# Cost at iteration 143 = 43.35290799260649
#
# Cost at iteration 144 = 42.88077080339324
#
# Cost at iteration 145 = 42.43151935958097
#
# Cost at iteration 146 = 42.004921086560124
#
# Cost at iteration 147 = 41.60069904471102
#
# Cost at iteration 148 = 41.218527300409
#
# Cost at iteration 149 = 40.858027664911646
#
# Cost at iteration 150 = 40.518766646555065
#
# Cost at iteration 151 = 40.200255765033425
#
# Cost at iteration 152 = 39.90195142622448
#
# Cost at iteration 153 = 39.62325739930953
#
# Cost at iteration 154 = 39.36352757213287
#
# Cost at iteration 155 = 39.12206811728958
#
# Cost at iteration 156 = 38.89814416609094
#
# Cost at iteration 157 = 38.69098704596619
#
# Cost at iteration 158 = 38.49980007474713
#
# Cost at iteration 159 = 38.323766846984256
#
# Cost at iteration 160 = 38.16205250430196
#
# Cost at iteration 161 = 38.01381363178248
#
# Cost at iteration 162 = 37.87820939501827
#
# Cost at iteration 163 = 37.75440623456525
#
# Cost at iteration 164 = 37.64158701652464
#
# Cost at iteration 165 = 37.53894866887103
#
# Cost at iteration 166 = 37.44571399039148
#
# Cost at iteration 167 = 37.36113285525824
#
# Cost at iteration 168 = 37.284488363456525
#
# Cost at iteration 169 = 37.21509679511994
#
# Cost at iteration 170 = 37.152311521968436
#
# Cost at iteration 171 = 37.095528260679444
#
# Cost at iteration 172 = 37.044176363522055
#
# Cost at iteration 173 = 36.99772756289851
#
# Cost at iteration 174 = 36.955689388351956
#
# Cost at iteration 175 = 36.91761265018484
#
# Cost at iteration 176 = 36.88308471167787
#
# Cost at iteration 177 = 36.85172726901731
#
# Cost at iteration 178 = 36.82319600719658
#
# Cost at iteration 179 = 36.79717779574586
#
# Cost at iteration 180 = 36.77339005509415
#
# Cost at iteration 181 = 36.75157830099906
#
# Cost at iteration 182 = 36.73151355109243
#
# Cost at iteration 183 = 36.71299053009136
#
# Cost at iteration 184 = 36.695826122558955
#
# Cost at iteration 185 = 36.67985773965831
#
# Cost at iteration 186 = 36.66455396897316
#
# Cost at iteration 187 = 36.64867617341473
#
# Cost at iteration 188 = 36.63238193580987
#
# Cost at iteration 189 = 36.61405506243536
#
# Cost at iteration 190 = 36.595937649390436
#
# Cost at iteration 191 = 36.578702877122545
#
# Cost at iteration 192 = 36.56227310120375
#
# Cost at iteration 193 = 36.546576584220645
#
# Cost at iteration 194 = 36.531056192088194
#
# Cost at iteration 195 = 36.51509443104542
#
# Cost at iteration 196 = 36.499390793760426
#
# Cost at iteration 197 = 36.48423742487404
#
# Cost at iteration 198 = 36.469480854350394
#
# Cost at iteration 199 = 36.45506383846203
#
# Cost at iteration 200 = 36.440931949959705
#
# Cost at iteration 201 = 36.427234687489864
#
# Cost at iteration 202 = 36.413308806409894
#
# Cost at iteration 203 = 36.39979528127181
#
# Cost at iteration 204 = 36.38667453752894
#
# Cost at iteration 205 = 36.3739205384842
#
# Cost at iteration 206 = 36.36150857587738
#
# Cost at iteration 207 = 36.3494158422168
#
# Cost at iteration 208 = 36.33762126007133
#
# Cost at iteration 209 = 36.32610525556482
#
# Cost at iteration 210 = 36.31484964651575
#
# Cost at iteration 211 = 36.30383753669829
#
# Cost at iteration 212 = 36.293053218460706
#
# Cost at iteration 213 = 36.28248208307673
#
# Cost at iteration 214 = 36.272110538219536
#
# Cost at iteration 215 = 36.261926204773765
#
# Cost at iteration 216 = 36.25191712533218
#
# Cost at iteration 217 = 36.24202911139426
#
# Cost at iteration 218 = 36.232143607682076
#
# Cost at iteration 219 = 36.22240846072567
#
# Cost at iteration 220 = 36.212815510930405
#
# Cost at iteration 221 = 36.20335623146788
#
# Cost at iteration 222 = 36.19402267862909
#
# Cost at iteration 223 = 36.18480750909512
#
# Cost at iteration 224 = 36.17570374852303
#
# Cost at iteration 225 = 36.166705022455375
#
# Cost at iteration 226 = 36.157805265074984
#
# Cost at iteration 227 = 36.148998787016815
#
# Cost at iteration 228 = 36.140280253661864
#
# Cost at iteration 229 = 36.13164466167155
#
# Cost at iteration 230 = 36.123087317171674
#
# Cost at iteration 231 = 36.114603815477686
#
# Cost at iteration 232 = 36.10619002224347
#
# Cost at iteration 233 = 36.09784205592574
#
# Cost at iteration 234 = 36.08955627146452
#
# Cost at iteration 235 = 36.081329245088476
#
# Cost at iteration 236 = 36.07315784761289
#
# Cost at iteration 237 = 36.06503905162414
#
# Cost at iteration 238 = 36.056969932946174
#
# Cost at iteration 239 = 36.048947823609915
#
# Cost at iteration 240 = 36.040970114549935
#
# Cost at iteration 241 = 36.03303452456237
#
# Cost at iteration 242 = 36.02513884731591
#
# Cost at iteration 243 = 36.01728099290718
#
# Cost at iteration 244 = 36.00945899425558
#
# Cost at iteration 245 = 36.001670999953674
#
# Cost at iteration 246 = 35.993915267143635
#
# Cost at iteration 247 = 35.98619015485191
#
# Cost at iteration 248 = 35.97849411775112
#
# Cost at iteration 249 = 35.97082570032005
#
# Cost at iteration 250 = 35.96318353137464
#
# Cost at iteration 251 = 35.95556631894478
#
# Cost at iteration 252 = 35.947972845473984
#
# Cost at iteration 253 = 35.94040196332014
#
# Cost at iteration 254 = 35.93285259053747
#
# Cost at iteration 255 = 35.925323706921255
#
# Cost at iteration 256 = 35.91781435029802
#
# Cost at iteration 257 = 35.91032361304504
#
# Cost at iteration 258 = 35.902850638824596
#
# Cost at iteration 259 = 35.89539461951899
#
# Cost at iteration 260 = 35.887954792353284
#
# Cost at iteration 261 = 35.880530437194075
#
# Cost at iteration 262 = 35.87312087401283
#
# Cost at iteration 263 = 35.865725460503626
#
# Cost at iteration 264 = 35.858343589845326
#
# Cost at iteration 265 = 35.850974688599315
#
# Cost at iteration 266 = 35.84361821473423
#
# Cost at iteration 267 = 35.83627365576977
#
# Cost at iteration 268 = 35.82894052703226
#
# Cost at iteration 269 = 35.821618370015024
#
# Cost at iteration 270 = 35.8143067508371
#
# Cost at iteration 271 = 35.807005258794234
#
# Cost at iteration 272 = 35.799713504996625
#
# Cost at iteration 273 = 35.79243112108787
#
# Cost at iteration 274 = 35.78515789086941
#
# Cost at iteration 275 = 35.7778934671832
#
# Cost at iteration 276 = 35.770637421694516
#
# Cost at iteration 277 = 35.76338945970481
#
# Cost at iteration 278 = 35.756149298766275
#
# Cost at iteration 279 = 35.74891667075472
#
# Cost at iteration 280 = 35.74169132101446
#
# Cost at iteration 281 = 35.7344730075736
#
# Cost at iteration 282 = 35.727261500405724
#
# Cost at iteration 283 = 35.72005658073523
#
# Cost at iteration 284 = 35.71285804038375
#
# Cost at iteration 285 = 35.70566568115515
#
# Cost at iteration 286 = 35.698479314256964
#
# Cost at iteration 287 = 35.691298759755824
#
# Cost at iteration 288 = 35.684123846065205
#
# Cost at iteration 289 = 35.67695440946325
#
# Cost at iteration 290 = 35.66979029363912
#
# Cost at iteration 291 = 35.66263134926603
#
# Cost at iteration 292 = 35.655477433599465
#
# Cost at iteration 293 = 35.64832841009915
#
# Cost at iteration 294 = 35.64118414807309
#
# Cost at iteration 295 = 35.634044522342826
#
# Cost at iteration 296 = 35.6269094129282
#
# Cost at iteration 297 = 35.619778704750814
#
# Cost at iteration 298 = 35.61265228735485
#
# Cost at iteration 299 = 35.605530054644404
#
# Cost at iteration 300 = 35.59841190463625
#
# Cost at iteration 301 = 35.591297739227116
#
# Cost at iteration 302 = 35.584187463974715
#
# Cost at iteration 303 = 35.57708098789165
#
# Cost at iteration 304 = 35.56997822325141
#
# Cost at iteration 305 = 35.56287908540586
#
# Cost at iteration 306 = 35.55578349261336
#
# Cost at iteration 307 = 35.548691365877126
#
# Cost at iteration 308 = 35.54160262879299
#
# Cost at iteration 309 = 35.534517207406175
#
# Cost at iteration 310 = 35.527435178634775
#
# Cost at iteration 311 = 35.52035678640589
#
# Cost at iteration 312 = 35.51328201488904
#
# Cost at iteration 313 = 35.506210384011425
#
# Cost at iteration 314 = 35.499141747976786
#
# Cost at iteration 315 = 35.49207605068856
#
# Cost at iteration 316 = 35.48501323154151
#
# Cost at iteration 317 = 35.47795323163593
#
# Cost at iteration 318 = 35.47089599357516
#
# Cost at iteration 319 = 35.46384120817732
#
# Cost at iteration 320 = 35.45678904629003
#
# Cost at iteration 321 = 35.44973947820884
#
# Cost at iteration 322 = 35.44269261835672
#
# Cost at iteration 323 = 35.43564831851315
#
# Cost at iteration 324 = 35.42860644526003
#
# Cost at iteration 325 = 35.42156757436747
#
# Cost at iteration 326 = 35.414531052549265
#
# Cost at iteration 327 = 35.407496843911055
#
# Cost at iteration 328 = 35.40046490186668
#
# Cost at iteration 329 = 35.39343518096512
#
# Cost at iteration 330 = 35.386407636575015
#
# Cost at iteration 331 = 35.379382061731924
#
# Cost at iteration 332 = 35.37235840161811
#
# Cost at iteration 333 = 35.36533678084923
#
# Cost at iteration 334 = 35.35831716146607
#
# Cost at iteration 335 = 35.351299502323066
#
# Cost at iteration 336 = 35.34428363497925
#
# Cost at iteration 337 = 35.33726854138644
#
# Cost at iteration 338 = 35.33025517855141
#
# Cost at iteration 339 = 35.32324360078636
#
# Cost at iteration 340 = 35.31623377034031
#
# Cost at iteration 341 = 35.309225596105875
#
# Cost at iteration 342 = 35.30221833774049
#
# Cost at iteration 343 = 35.295212696056815
#
# Cost at iteration 344 = 35.288208645249185
#
# Cost at iteration 345 = 35.28120614902053
#
# Cost at iteration 346 = 35.274205171814025
#
# Cost at iteration 347 = 35.26720567846412
#
# Cost at iteration 348 = 35.260207634192355
#
# Cost at iteration 349 = 35.25321100459378
#
# Cost at iteration 350 = 35.24621559735099
#
# Cost at iteration 351 = 35.239221522385726
#
# Cost at iteration 352 = 35.23222829512111
#
# Cost at iteration 353 = 35.22523630454076
#
# Cost at iteration 354 = 35.21824605249905
#
# Cost at iteration 355 = 35.21125781027513
#
# Cost at iteration 356 = 35.2042707981266
#
# Cost at iteration 357 = 35.1972851383121
#
# Cost at iteration 358 = 35.19030056870165
#
# Cost at iteration 359 = 35.18331642499151
#
# Cost at iteration 360 = 35.17633327872201
#
# Cost at iteration 361 = 35.169351079839856
#
# Cost at iteration 362 = 35.16237003002529
#
# Cost at iteration 363 = 35.15539044174331
#
# Cost at iteration 364 = 35.14841215268088
#
# Cost at iteration 365 = 35.14143476596718
#
# Cost at iteration 366 = 35.1344584739633
#
# Cost at iteration 367 = 35.12748237418617
#
# Cost at iteration 368 = 35.12050772721311
#
# Cost at iteration 369 = 35.11353523295623
#
# Cost at iteration 370 = 35.10656485167113
#
# Cost at iteration 371 = 35.09959561785307
#
# Cost at iteration 372 = 35.09262639336179
#
# Cost at iteration 373 = 35.085657639854055
#
# Cost at iteration 374 = 35.07868987938313
#
# Cost at iteration 375 = 35.071720913508145
#
# Cost at iteration 376 = 35.06475336155635
#
# Cost at iteration 377 = 35.057786505859475
#
# Cost at iteration 378 = 35.0508199654823
#
# Cost at iteration 379 = 35.043854140964925
#
# Cost at iteration 380 = 35.03688878836591
#
# Cost at iteration 381 = 35.02992390657691
#
# Cost at iteration 382 = 35.022959535643594
#
# Cost at iteration 383 = 35.015996115346645
#
# Cost at iteration 384 = 35.00903309579505
#
# Cost at iteration 385 = 35.0020683482993
#
# Cost at iteration 386 = 34.99510215148936
#
# Cost at iteration 387 = 34.98813384450022
#
# Cost at iteration 388 = 34.981164640864804
#
# Cost at iteration 389 = 34.97419581372392
#
# Cost at iteration 390 = 34.96722663874068
#
# Cost at iteration 391 = 34.96025796474413
#
# Cost at iteration 392 = 34.953289406235555
#
# Cost at iteration 393 = 34.94632135040121
#
# Cost at iteration 394 = 34.93935367216617
#
# Cost at iteration 395 = 34.93238585481448
#
# Cost at iteration 396 = 34.92541648974545
#
# Cost at iteration 397 = 34.918446140792085
#
# Cost at iteration 398 = 34.911476876995906
#
# Cost at iteration 399 = 34.90450764399232
#
# Cost at iteration 400 = 34.89753836535621
#
# Cost at iteration 401 = 34.890569039201736
#
# Cost at iteration 402 = 34.883600094395135
#
# Cost at iteration 403 = 34.87663167748894
#
# Cost at iteration 404 = 34.869663141067385
#
# Cost at iteration 405 = 34.86269450207672
#
# Cost at iteration 406 = 34.85572573077617
#
# Cost at iteration 407 = 34.84875656399564
#
# Cost at iteration 408 = 34.841787227701715
#
# Cost at iteration 409 = 34.8348181134868
#
# Cost at iteration 410 = 34.827849108776746
#
# Cost at iteration 411 = 34.820879317650444
#
# Cost at iteration 412 = 34.813906859180314
#
# Cost at iteration 413 = 34.80693407470095
#
# Cost at iteration 414 = 34.7999609535431
#
# Cost at iteration 415 = 34.79298764324485
#
# Cost at iteration 416 = 34.786014530889744
#
# Cost at iteration 417 = 34.77904100379142
#
# Cost at iteration 418 = 34.77206705741566
#
# Cost at iteration 419 = 34.7650920721836
#
# Cost at iteration 420 = 34.75811655853953
#
# Cost at iteration 421 = 34.75114065147106
#
# Cost at iteration 422 = 34.744162823617486
#
# Cost at iteration 423 = 34.73718450786816
#
# Cost at iteration 424 = 34.730205624904414
#
# Cost at iteration 425 = 34.72322525461371
#
# Cost at iteration 426 = 34.716244102655935
#
# Cost at iteration 427 = 34.70926239552137
#
# Cost at iteration 428 = 34.70228058705198
#
# Cost at iteration 429 = 34.69529790143646
#
# Cost at iteration 430 = 34.688314424055875
#
# Cost at iteration 431 = 34.68133043726088
#
# Cost at iteration 432 = 34.67434711538664
#
# Cost at iteration 433 = 34.66736490257781
#
# Cost at iteration 434 = 34.66037992317987
#
# Cost at iteration 435 = 34.65339366329664
#
# Cost at iteration 436 = 34.64640661352842
#
# Cost at iteration 437 = 34.63941863325559
#
# Cost at iteration 438 = 34.632430447470654
#
# Cost at iteration 439 = 34.62544175876927
#
# Cost at iteration 440 = 34.61845226452049
#
# Cost at iteration 441 = 34.61146192848938
#
# Cost at iteration 442 = 34.60447089361171
#
# Cost at iteration 443 = 34.59747903358381
#
# Cost at iteration 444 = 34.59048574528641
#
# Cost at iteration 445 = 34.58349151080852
#
# Cost at iteration 446 = 34.57649692264115
#
# Cost at iteration 447 = 34.56950198576649
#
# Cost at iteration 448 = 34.56250698740208
#
# Cost at iteration 449 = 34.555511071606546
#
# Cost at iteration 450 = 34.54851458397894
#
# Cost at iteration 451 = 34.54151793979496
#
# Cost at iteration 452 = 34.53452033953376
#
# Cost at iteration 453 = 34.527521781199205
#
# Cost at iteration 454 = 34.520522243729815
#
# Cost at iteration 455 = 34.51352170843691
#
# Cost at iteration 456 = 34.506520247693516
#
# Cost at iteration 457 = 34.49951776001867
#
# Cost at iteration 458 = 34.492514394827246
#
# Cost at iteration 459 = 34.48551018043524
#
# Cost at iteration 460 = 34.478503669257144
#
# Cost at iteration 461 = 34.471495609129235
#
# Cost at iteration 462 = 34.464486450383134
#
# Cost at iteration 463 = 34.457476346149946
#
# Cost at iteration 464 = 34.45046582522735
#
# Cost at iteration 465 = 34.44345459054171
#
# Cost at iteration 466 = 34.43644266215345
#
# Cost at iteration 467 = 34.429430115241146
#
# Cost at iteration 468 = 34.42241784432624
#
# Cost at iteration 469 = 34.415404801305286
#
# Cost at iteration 470 = 34.40839062267877
#
# Cost at iteration 471 = 34.40137615759512
#
# Cost at iteration 472 = 34.39436159267734
#
# Cost at iteration 473 = 34.38734676483904
#
# Cost at iteration 474 = 34.38033183585718
#
# Cost at iteration 475 = 34.37331565403524
#
# Cost at iteration 476 = 34.366298316792005
#
# Cost at iteration 477 = 34.359279394802385
#
# Cost at iteration 478 = 34.35225937060651
#
# Cost at iteration 479 = 34.34523850698108
#
# Cost at iteration 480 = 34.338213428614644
#
# Cost at iteration 481 = 34.33118522752046
#
# Cost at iteration 482 = 34.32415578339685
#
# Cost at iteration 483 = 34.317125110855336
#
# Cost at iteration 484 = 34.310093191297945
#
# Cost at iteration 485 = 34.30306001075718
#
# Cost at iteration 486 = 34.29602555554206
#
# Cost at iteration 487 = 34.288989812700976
#
# Cost at iteration 488 = 34.28195276993341
#
# Cost at iteration 489 = 34.27491464890138
#
# Cost at iteration 490 = 34.267854288349746
#
# Cost at iteration 491 = 34.2607412592822
#
# Cost at iteration 492 = 34.25362524102469
#
# Cost at iteration 493 = 34.24650643288323
#
# Cost at iteration 494 = 34.2393840282177
#
# Cost at iteration 495 = 34.23225911908788
#
# Cost at iteration 496 = 34.2251319461872
#
# Cost at iteration 497 = 34.21800199273319
#
# Cost at iteration 498 = 34.210865711208285
#
# Cost at iteration 499 = 34.2037267624149
#
# Cost at iteration 500 = 34.19658452561168
#
# Cost at iteration 501 = 34.189438974039916
#
# Cost at iteration 502 = 34.182287762492514
#
# Cost at iteration 503 = 34.1751343454677
#
# Cost at iteration 504 = 34.16797771851138
#
# Cost at iteration 505 = 34.16081830708415
#
# Cost at iteration 506 = 34.1536562648814
#
# Cost at iteration 507 = 34.146491027387974
#
# Cost at iteration 508 = 34.13932290125968
#
# Cost at iteration 509 = 34.13215264951607
#
# Cost at iteration 510 = 34.12498070323077
#
# Cost at iteration 511 = 34.11780694495839
#
# Cost at iteration 512 = 34.11062708235588
#
# Cost at iteration 513 = 34.10344346584392
#
# Cost at iteration 514 = 34.09625714617063
#
# Cost at iteration 515 = 34.08906639970478
#
# Cost at iteration 516 = 34.081873545517915
#
# Cost at iteration 517 = 34.074678688758496
#
# Cost at iteration 518 = 34.067481842424016
#
# Cost at iteration 519 = 34.06028301001459
#
# Cost at iteration 520 = 34.05308219638574
#
# Cost at iteration 521 = 34.045876327225386
#
# Cost at iteration 522 = 34.03866855385771
#
# Cost at iteration 523 = 34.031458826700955
#
# Cost at iteration 524 = 34.024247148858585
#
# Cost at iteration 525 = 34.01703352366519
#
# Cost at iteration 526 = 34.00981795465216
#
# Cost at iteration 527 = 34.002600445560084
#
# Cost at iteration 528 = 33.995380233643765
#
# Cost at iteration 529 = 33.988156640543
#
# Cost at iteration 530 = 33.980929696157204
#
# Cost at iteration 531 = 33.973700895617135
#
# Cost at iteration 532 = 33.96646736416074
#
# Cost at iteration 533 = 33.95923012400401
#
# Cost at iteration 534 = 33.95199096738963
#
# Cost at iteration 535 = 33.94475039599164
#
# Cost at iteration 536 = 33.937508172743414
#
# Cost at iteration 537 = 33.93026407710681
#
# Cost at iteration 538 = 33.92301499013147
#
# Cost at iteration 539 = 33.91576261526381
#
# Cost at iteration 540 = 33.90850836839986
#
# Cost at iteration 541 = 33.901252259264574
#
# Cost at iteration 542 = 33.89399429203495
#
# Cost at iteration 543 = 33.88673497666127
#
# Cost at iteration 544 = 33.879473832361995
#
# Cost at iteration 545 = 33.87221086469431
#
# Cost at iteration 546 = 33.864946076223724
#
# Cost at iteration 547 = 33.85767676759659
#
# Cost at iteration 548 = 33.850403861800736
#
# Cost at iteration 549 = 33.843129139520364
#
# Cost at iteration 550 = 33.83585323836817
#
# Cost at iteration 551 = 33.82857563539028
#
# Cost at iteration 552 = 33.82129626319174
#
# Cost at iteration 553 = 33.814015129815004
#
# Cost at iteration 554 = 33.806731129095034
#
# Cost at iteration 555 = 33.79944493128527
#
# Cost at iteration 556 = 33.79215635401662
#
# Cost at iteration 557 = 33.784865982202724
#
# Cost at iteration 558 = 33.77757390690098
#
# Cost at iteration 559 = 33.77028013628672
#
# Cost at iteration 560 = 33.76298388756933
#
# Cost at iteration 561 = 33.755685159782075
#
# Cost at iteration 562 = 33.7483838440151
#
# Cost at iteration 563 = 33.741080848808274
#
# Cost at iteration 564 = 33.733776229138364
#
# Cost at iteration 565 = 33.72646989975703
#
# Cost at iteration 566 = 33.719160766411996
#
# Cost at iteration 567 = 33.71185002147648
#
# Cost at iteration 568 = 33.704537713566715
#
# Cost at iteration 569 = 33.69722384940757
#
# Cost at iteration 570 = 33.68990844485032
#
# Cost at iteration 571 = 33.68259151441867
#
# Cost at iteration 572 = 33.675270868031234
#
# Cost at iteration 573 = 33.66794852891747
#
# Cost at iteration 574 = 33.660592521451626
#
# Cost at iteration 575 = 33.65315348258871
#
# Cost at iteration 576 = 33.64570966252365
#
# Cost at iteration 577 = 33.63826240429133
#
# Cost at iteration 578 = 33.630812123540025
#
# Cost at iteration 579 = 33.6233589598043
#
# Cost at iteration 580 = 33.61590300331734
#
# Cost at iteration 581 = 33.608444347394446
#
# Cost at iteration 582 = 33.60098405268977
#
# Cost at iteration 583 = 33.59352170699443
#
# Cost at iteration 584 = 33.586056916733476
#
# Cost at iteration 585 = 33.578589759386304
#
# Cost at iteration 586 = 33.571119601064794
#
# Cost at iteration 587 = 33.563645422083376
#
# Cost at iteration 588 = 33.55616993175648
#
# Cost at iteration 589 = 33.548692989217194
#
# Cost at iteration 590 = 33.54120440563985
#
# Cost at iteration 591 = 33.533685734046685
#
# Cost at iteration 592 = 33.52616385933619
#
# Cost at iteration 593 = 33.518639526058706
#
# Cost at iteration 594 = 33.51111267697649
#
# Cost at iteration 595 = 33.50358344106842
#
# Cost at iteration 596 = 33.49605172908755
#
# Cost at iteration 597 = 33.488517282408196
#
# Cost at iteration 598 = 33.48098064934702
#
# Cost at iteration 599 = 33.47344191760015
#
# Cost at iteration 600 = 33.46590190152942
#
# Cost at iteration 601 = 33.45835922155625
#
# Cost at iteration 602 = 33.45081463619046
#
# Cost at iteration 603 = 33.44326820494648
#
# Cost at iteration 604 = 33.435719977865595
#
# Cost at iteration 605 = 33.428170004938124
#
# Cost at iteration 606 = 33.42061833394276
#
# Cost at iteration 607 = 33.41306501122486
#
# Cost at iteration 608 = 33.40551008170047
#
# Cost at iteration 609 = 33.39795358904309
#
# Cost at iteration 610 = 33.39039557580707
#
# Cost at iteration 611 = 33.38283608355284
#
# Cost at iteration 612 = 33.3752746626628
#
# Cost at iteration 613 = 33.36769394205418
#
# Cost at iteration 614 = 33.36011128239476
#
# Cost at iteration 615 = 33.352526983560395
#
# Cost at iteration 616 = 33.34494195898127
#
# Cost at iteration 617 = 33.33735557465008
#
# Cost at iteration 618 = 33.329767700111766
#
# Cost at iteration 619 = 33.32217839080514
#
# Cost at iteration 620 = 33.31458770027594
#
# Cost at iteration 621 = 33.30696465866449
#
# Cost at iteration 622 = 33.29933267226656
#
# Cost at iteration 623 = 33.29169874075001
#
# Cost at iteration 624 = 33.28406293544928
#
# Cost at iteration 625 = 33.27642535891634
#
# Cost at iteration 626 = 33.268786097570455
#
# Cost at iteration 627 = 33.26114523609407
#
# Cost at iteration 628 = 33.253502853850826
#
# Cost at iteration 629 = 33.245836735682396
#
# Cost at iteration 630 = 33.23815378599587
#
# Cost at iteration 631 = 33.23046900810109
#
# Cost at iteration 632 = 33.22278255735409
#
# Cost at iteration 633 = 33.21509450798901
#
# Cost at iteration 634 = 33.20740114940789
#
# Cost at iteration 635 = 33.199691275224374
#
# Cost at iteration 636 = 33.19197958344598
#
# Cost at iteration 637 = 33.18426634909385
#
# Cost at iteration 638 = 33.17648018817996
#
# Cost at iteration 639 = 33.16868719968264
#
# Cost at iteration 640 = 33.16089222155004
#
# Cost at iteration 641 = 33.15309527703191
#
# Cost at iteration 642 = 33.145296520337645
#
# Cost at iteration 643 = 33.137496053172406
#
# Cost at iteration 644 = 33.12969398464528
#
# Cost at iteration 645 = 33.1218904128815
#
# Cost at iteration 646 = 33.11408543184475
#
# Cost at iteration 647 = 33.106279129887604
#
# Cost at iteration 648 = 33.0984715909313
#
# Cost at iteration 649 = 33.090663368229386
#
# Cost at iteration 650 = 33.082846413625425
#
# Cost at iteration 651 = 33.075016140341816
#
# Cost at iteration 652 = 33.067165146842235
#
# Cost at iteration 653 = 33.059297072568384
#
# Cost at iteration 654 = 33.05142756016512
#
# Cost at iteration 655 = 33.04355680259952
#
# Cost at iteration 656 = 33.03565645874875
#
# Cost at iteration 657 = 33.02773965464669
#
# Cost at iteration 658 = 33.01982147934366
#
# Cost at iteration 659 = 33.0119020532395
#
# Cost at iteration 660 = 33.00394575455186
#
# Cost at iteration 661 = 32.9958850401412
#
# Cost at iteration 662 = 32.98781426449709
#
# Cost at iteration 663 = 32.97974197800873
#
# Cost at iteration 664 = 32.971668225157266
#
# Cost at iteration 665 = 32.96359311627584
#
# Cost at iteration 666 = 32.95551719614038
#
# Cost at iteration 667 = 32.94744040403701
#
# Cost at iteration 668 = 32.93936250680864
#
# Cost at iteration 669 = 32.93128358130175
#
# Cost at iteration 670 = 32.92320369860635
#
# Cost at iteration 671 = 32.91512292825117
#
# Cost at iteration 672 = 32.90704133704679
#
# Cost at iteration 673 = 32.898958989913595
#
# Cost at iteration 674 = 32.89087594991241
#
# Cost at iteration 675 = 32.882792278544244
#
# Cost at iteration 676 = 32.87470803591329
#
# Cost at iteration 677 = 32.8666232809132
#
# Cost at iteration 678 = 32.85853807137768
#
# Cost at iteration 679 = 32.8504524642208
#
# Cost at iteration 680 = 32.84236651555987
#
# Cost at iteration 681 = 32.834280280825666
#
# Cost at iteration 682 = 32.8261938148603
#
# Cost at iteration 683 = 32.81810717200425
#
# Cost at iteration 684 = 32.8100204061737
#
# Cost at iteration 685 = 32.80193302384749
#
# Cost at iteration 686 = 32.79384483863839
#
# Cost at iteration 687 = 32.785756506187994
#
# Cost at iteration 688 = 32.77766792415799
#
# Cost at iteration 689 = 32.76957949364586
#
# Cost at iteration 690 = 32.76149127253719
#
# Cost at iteration 691 = 32.75340331064907
#
# Cost at iteration 692 = 32.74531566117793
#
# Cost at iteration 693 = 32.73722837588528
#
# Cost at iteration 694 = 32.729141507172095
#
# Cost at iteration 695 = 32.72102042330076
#
# Cost at iteration 696 = 32.71289216860658
#
# Cost at iteration 697 = 32.70476427374076
#
# Cost at iteration 698 = 32.69663678706199
#
# Cost at iteration 699 = 32.688509772059376
#
# Cost at iteration 700 = 32.68038328463116
#
# Cost at iteration 701 = 32.67225738324563
#
# Cost at iteration 702 = 32.66413212454242
#
# Cost at iteration 703 = 32.65600756539425
#
# Cost at iteration 704 = 32.64788376206958
#
# Cost at iteration 705 = 32.63976077068711
#
# Cost at iteration 706 = 32.63163864707753
#
# Cost at iteration 707 = 32.62351744690599
#
# Cost at iteration 708 = 32.61539552169194
#
# Cost at iteration 709 = 32.60727207903975
#
# Cost at iteration 710 = 32.59914972452733
#
# Cost at iteration 711 = 32.59102851593373
#
# Cost at iteration 712 = 32.58290850715464
#
# Cost at iteration 713 = 32.57478978069931
#
# Cost at iteration 714 = 32.5666726319708
#
# Cost at iteration 715 = 32.55855685371251
#
# Cost at iteration 716 = 32.550442507124295
#
# Cost at iteration 717 = 32.54232964403058
#
# Cost at iteration 718 = 32.5342183208372
#
# Cost at iteration 719 = 32.526108591778794
#
# Cost at iteration 720 = 32.518000512205546
#
# Cost at iteration 721 = 32.50989287205445
#
# Cost at iteration 722 = 32.501786816160745
#
# Cost at iteration 723 = 32.49360228211282
#
# Cost at iteration 724 = 32.48541197891908
#
# Cost at iteration 725 = 32.477223347579276
#
# Cost at iteration 726 = 32.46903644457762
#
# Cost at iteration 727 = 32.46085132456839
#
# Cost at iteration 728 = 32.45266804330977
#
# Cost at iteration 729 = 32.44448665614789
#
# Cost at iteration 730 = 32.43630721877229
#
# Cost at iteration 731 = 32.4281297868096
#
# Cost at iteration 732 = 32.41995441601707
#
# Cost at iteration 733 = 32.41178116216701
#
# Cost at iteration 734 = 32.40361008109308
#
# Cost at iteration 735 = 32.39544122865279
#
# Cost at iteration 736 = 32.387274660734796
#
# Cost at iteration 737 = 32.37911043324305
#
# Cost at iteration 738 = 32.3709486020938
#
# Cost at iteration 739 = 32.36278922320602
#
# Cost at iteration 740 = 32.3546323524958
#
# Cost at iteration 741 = 32.34647804586872
#
# Cost at iteration 742 = 32.33832635921373
#
# Cost at iteration 743 = 32.330177348396255
#
# Cost at iteration 744 = 32.32203106925189
#
# Cost at iteration 745 = 32.31388757757999
#
# Cost at iteration 746 = 32.30574692913732
#
# Cost at iteration 747 = 32.29760917963186
#
# Cost at iteration 748 = 32.28947438471655
#
# Cost at iteration 749 = 32.281342599983105
#
# Cost at iteration 750 = 32.273213880955964
#
# Cost at iteration 751 = 32.26508828308609
#
# Cost at iteration 752 = 32.256965861744945
#
# Cost at iteration 753 = 32.24884667221848
#
# Cost at iteration 754 = 32.24073076970101
#
# Cost at iteration 755 = 32.23261820928927
#
# Cost at iteration 756 = 32.22450904597644
#
# Cost at iteration 757 = 32.2164033346461
#
# Cost at iteration 758 = 32.20830113006633
#
# Cost at iteration 759 = 32.20020248688377
#
# Cost at iteration 760 = 32.19210745961765
#
# Cost at iteration 761 = 32.18401610265391
#
# Cost at iteration 762 = 32.175928470239306
#
# Cost at iteration 763 = 32.1678446164755
#
# Cost at iteration 764 = 32.159764595313234
#
# Cost at iteration 765 = 32.15168846054646
#
# Cost at iteration 766 = 32.14361626580649
#
# Cost at iteration 767 = 32.13554806455626
#
# Cost at iteration 768 = 32.1274839100844
#
# Cost at iteration 769 = 32.1194238554996
#
# Cost at iteration 770 = 32.11136795372475
#
# Cost at iteration 771 = 32.10331625749126
#
# Cost at iteration 772 = 32.09526881933336
#
# Cost at iteration 773 = 32.08722569158233
#
# Cost at iteration 774 = 32.079185682295126
#
# Cost at iteration 775 = 32.071148740946924
#
# Cost at iteration 776 = 32.063116271286205
#
# Cost at iteration 777 = 32.055088324796415
#
# Cost at iteration 778 = 32.047064952776296
#
# Cost at iteration 779 = 32.03904620625652
#
# Cost at iteration 780 = 32.03103213604482
#
# Cost at iteration 781 = 32.02302279268757
#
# Cost at iteration 782 = 32.01501822648597
#
# Cost at iteration 783 = 32.0070184874765
#
# Cost at iteration 784 = 31.99902362543494
#
# Cost at iteration 785 = 31.991033689864835
#
# Cost at iteration 786 = 31.98304872999636
#
# Cost at iteration 787 = 31.975068794778323
#
# Cost at iteration 788 = 31.96709393287483
#
# Cost at iteration 789 = 31.959124192658837
#
# Cost at iteration 790 = 31.951159622207882
#
# Cost at iteration 791 = 31.943200269298472
#
# Cost at iteration 792 = 31.935246181401347
#
# Cost at iteration 793 = 31.92729740567627
#
# Cost at iteration 794 = 31.91935398896728
#
# Cost at iteration 795 = 31.911415977797603
#
# Cost at iteration 796 = 31.903483418364903
#
# Cost at iteration 797 = 31.895556356536435
#
# Cost at iteration 798 = 31.887634837844278
#
# Cost at iteration 799 = 31.879718907480633
#
# Cost at iteration 800 = 31.871808610293186
#
# Cost at iteration 801 = 31.863903990780454
#
# Cost at iteration 802 = 31.85600509308728
#
# Cost at iteration 803 = 31.848111961000306
#
# Cost at iteration 804 = 31.84022463794355
#
# Cost at iteration 805 = 31.832343166974
#
# Cost at iteration 806 = 31.824467590777317
#
# Cost at iteration 807 = 31.816597951663535
#
# Cost at iteration 808 = 31.808734291562875
#
# Cost at iteration 809 = 31.80087665202158
#
# Cost at iteration 810 = 31.793025187533754
#
# Cost at iteration 811 = 31.785179860269203
#
# Cost at iteration 812 = 31.77734068479102
#
# Cost at iteration 813 = 31.769507701125043
#
# Cost at iteration 814 = 31.76168094877814
#
# Cost at iteration 815 = 31.75386046693534
#
# Cost at iteration 816 = 31.746046294303262
#
# Cost at iteration 817 = 31.738238469223518
#
# Cost at iteration 818 = 31.73043691604839
#
# Cost at iteration 819 = 31.72263821956361
#
# Cost at iteration 820 = 31.714845989242956
#
# Cost at iteration 821 = 31.707060261661205
#
# Cost at iteration 822 = 31.699281073112907
#
# Cost at iteration 823 = 31.69150598201402
#
# Cost at iteration 824 = 31.683736850065102
#
# Cost at iteration 825 = 31.675974370075128
#
# Cost at iteration 826 = 31.668218576564215
#
# Cost at iteration 827 = 31.660467369560035
#
# Cost at iteration 828 = 31.652721672058327
#
# Cost at iteration 829 = 31.644982768592836
#
# Cost at iteration 830 = 31.637250691848813
#
# Cost at iteration 831 = 31.629525474045884
#
# Cost at iteration 832 = 31.621807146942583
#
# Cost at iteration 833 = 31.614095741828304
#
# Cost at iteration 834 = 31.606391289525735
#
# Cost at iteration 835 = 31.5986938203847
#
# Cost at iteration 836 = 31.59100336428326
#
# Cost at iteration 837 = 31.583319950622876
#
# Cost at iteration 838 = 31.575643608328654
#
# Cost at iteration 839 = 31.56797436584544
#
# Cost at iteration 840 = 31.560312251137553
#
# Cost at iteration 841 = 31.55265729168554
#
# Cost at iteration 842 = 31.545009514485606
#
# Cost at iteration 843 = 31.537368946046897
#
# Cost at iteration 844 = 31.529735612390777
#
# Cost at iteration 845 = 31.522109539048483
#
# Cost at iteration 846 = 31.51449075106033
#
# Cost at iteration 847 = 31.50687927297374
#
# Cost at iteration 848 = 31.499275128842392
#
# Cost at iteration 849 = 31.491678342224553
#
# Cost at iteration 850 = 31.48408893618229
#
# Cost at iteration 851 = 31.47650693328001
#
# Cost at iteration 852 = 31.468932355583753
#
# Cost at iteration 853 = 31.461365224659975
#
# Cost at iteration 854 = 31.453805561574896
#
# Cost at iteration 855 = 31.44625338689349
#
# Cost at iteration 856 = 31.43870872067899
#
# Cost at iteration 857 = 31.431171582492
#
# Cost at iteration 858 = 31.423641991390134
#
# Cost at iteration 859 = 31.416119965927383
#
# Cost at iteration 860 = 31.408605524153746
#
# Cost at iteration 861 = 31.401098683614855
#
# Cost at iteration 862 = 31.393599461351737
#
# Cost at iteration 863 = 31.386107873900542
#
# Cost at iteration 864 = 31.378623937292527
#
# Cost at iteration 865 = 31.371147667053876
#
# Cost at iteration 866 = 31.363679078205813
#
# Cost at iteration 867 = 31.35621818526462
#
# Cost at iteration 868 = 31.348765002241866
#
# Cost at iteration 869 = 31.341319542644566
#
# Cost at iteration 870 = 31.33388181947555
#
# Cost at iteration 871 = 31.3264518452338
#
# Cost at iteration 872 = 31.319029631914894
#
# Cost at iteration 873 = 31.311615191011516
#
# Cost at iteration 874 = 31.304208533514053
#
# Cost at iteration 875 = 31.29680966991122
#
# Cost at iteration 876 = 31.289418610190793
#
# Cost at iteration 877 = 31.282035363840365
#
# Cost at iteration 878 = 31.274659939848245
#
# Cost at iteration 879 = 31.26729234670429
#
# Cost at iteration 880 = 31.25993259240096
#
# Cost at iteration 881 = 31.252580684434314
#
# Cost at iteration 882 = 31.245236629805134
#
# Cost at iteration 883 = 31.23790043502006
#
# Cost at iteration 884 = 31.230572106092875
#
# Cost at iteration 885 = 31.22325164854572
#
# Cost at iteration 886 = 31.215939067410524
#
# Cost at iteration 887 = 31.20863436723034
#
# Cost at iteration 888 = 31.20133755206086
#
# Cost at iteration 889 = 31.194048625471915
#
# Cost at iteration 890 = 31.18676759054907
#
# Cost at iteration 891 = 31.179494449895255
#
# Cost at iteration 892 = 31.172229205632462
#
# Cost at iteration 893 = 31.164971859403476
#
# Cost at iteration 894 = 31.157722412373726
#
# Cost at iteration 895 = 31.150480865233064
#
# Cost at iteration 896 = 31.143247218197725
#
# Cost at iteration 897 = 31.13602147101227
#
# Cost at iteration 898 = 31.128803622951615
#
# Cost at iteration 899 = 31.121593672823003
#
# Cost at iteration 900 = 31.114391618968234
#
# Cost at iteration 901 = 31.107197459265688
#
# Cost at iteration 902 = 31.100011191132662
#
# Cost at iteration 903 = 31.09283281152744
#
# Cost at iteration 904 = 31.08566231695177
#
# Cost at iteration 905 = 31.078499703453023
#
# Cost at iteration 906 = 31.071344966626718
#
# Cost at iteration 907 = 31.064198101618768
#
# Cost at iteration 908 = 31.05705910312815
#
# Cost at iteration 909 = 31.049927965409175
#
# Cost at iteration 910 = 31.042804682274227
#
# Cost at iteration 911 = 31.035689247096126
#
# Cost at iteration 912 = 31.028581652810985
#
# Cost at iteration 913 = 31.021481891920573
#
# Cost at iteration 914 = 31.014389956495304
#
# Cost at iteration 915 = 31.007305838176627
#
# Cost at iteration 916 = 31.0002295281801
#
# Cost at iteration 917 = 30.9931610172978
#
# Cost at iteration 918 = 30.986100295901608
#
# Cost at iteration 919 = 30.979047353945475
#
# Cost at iteration 920 = 30.972002180968932
#
# Cost at iteration 921 = 30.964964766099246
#
# Cost at iteration 922 = 30.957935098055238
#
# Cost at iteration 923 = 30.95091316514921
#
# Cost at iteration 924 = 30.94389895529105
#
# Cost at iteration 925 = 30.93689245598996
#
# Cost at iteration 926 = 30.92989365435896
#
# Cost at iteration 927 = 30.922902537116222
#
# Cost at iteration 928 = 30.91591909059011
#
# Cost at iteration 929 = 30.90894330071997
#
# Cost at iteration 930 = 30.90197515306196
#
# Cost at iteration 931 = 30.89501463278894
#
# Cost at iteration 932 = 30.888061724697476
#
# Cost at iteration 933 = 30.88111641320638
#
# Cost at iteration 934 = 30.87417868236546
#
# Cost at iteration 935 = 30.867248515851976
#
# Cost at iteration 936 = 30.86032589698202
#
# Cost at iteration 937 = 30.853410808703774
#
# Cost at iteration 938 = 30.846503233612907
#
# Cost at iteration 939 = 30.839603153941002
#
# Cost at iteration 940 = 30.832710551576884
#
# Cost at iteration 941 = 30.825825408047752
#
# Cost at iteration 942 = 30.818947704549647
#
# Cost at iteration 943 = 30.812077421917234
#
# Cost at iteration 944 = 30.805214540668544
#
# Cost at iteration 945 = 30.798359040956747
#
# Cost at iteration 946 = 30.791510902637732
#
# Cost at iteration 947 = 30.784670105192973
#
# Cost at iteration 948 = 30.777836627833832
#
# Cost at iteration 949 = 30.771010449377727
#
# Cost at iteration 950 = 30.764191548412
#
# Cost at iteration 951 = 30.757379903093867
#
# Cost at iteration 952 = 30.750575491412295
#
# Cost at iteration 953 = 30.74377829086154
#
# Cost at iteration 954 = 30.736988278866562
#
# Cost at iteration 955 = 30.730205432244574
#
# Cost at iteration 956 = 30.72342972790632
#
# Cost at iteration 957 = 30.71666114195785
#
# Cost at iteration 958 = 30.7098996508731
#
# Cost at iteration 959 = 30.703145229977743
#
# Cost at iteration 960 = 30.69639785543659
#
# Cost at iteration 961 = 30.68965750166373
#
# Cost at iteration 962 = 30.682924144736745
#
# Cost at iteration 963 = 30.67619775791902
#
# Cost at iteration 964 = 30.669478317605016
#
# Cost at iteration 965 = 30.662765795487083
#
# Cost at iteration 966 = 30.65606016905233
#
# Cost at iteration 967 = 30.6493614077269
#
# Cost at iteration 968 = 30.64266949168423
#
# Cost at iteration 969 = 30.635984387100578
#
# Cost at iteration 970 = 30.629306080424055
#
# Cost at iteration 971 = 30.62263453390262
#
# Cost at iteration 972 = 30.615969749339865
#
# Cost at iteration 973 = 30.60931168821881
#
# Cost at iteration 974 = 30.602660393840058
#
# Cost at iteration 975 = 30.596015850228316
#
# Cost at iteration 976 = 30.58937822698576
#
# Cost at iteration 977 = 30.582747644005348
#
# Cost at iteration 978 = 30.57612469973839
#
# Cost at iteration 979 = 30.569510147187472
#
# Cost at iteration 980 = 30.562906170300018
#
# Cost at iteration 981 = 30.556316275447152
#
# Cost at iteration 982 = 30.549748879626907
#
# Cost at iteration 983 = 30.543219272434424
#
# Cost at iteration 984 = 30.536761501760388
#
# Cost at iteration 985 = 30.53044149138338
#
# Cost at iteration 986 = 30.524402522581653
#
# Cost at iteration 987 = 30.51893073037037
#
# Cost at iteration 988 = 30.51465005335869
#
# Cost at iteration 989 = 30.512817396555956
#
# Cost at iteration 990 = 30.516241432274054
#
# Cost at iteration 991 = 30.530499435816285
#
# Cost at iteration 992 = 30.56870482292157
#
# Cost at iteration 993 = 30.655585968580525
#
# Cost at iteration 994 = 30.847924843748636
#
# Cost at iteration 995 = 31.271121119437673
#
# Cost at iteration 996 = 32.16900557578501
#
# Cost at iteration 997 = 34.09900599778724
#
# Cost at iteration 998 = 37.814324853376334
#
# Cost at iteration 999 = 45.5413861358932
#
# Cost at iteration 1000 = 60.64212480386478
#
# Root Mean Squared Error on Training Data = 12.383947387722507
# Root Mean Squared Error on Test Data = 12.878039169658933
